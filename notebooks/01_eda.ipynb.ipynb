# %%
import pandas as pd

X_train = pd.read_csv("../data/raw/train_features.csv")
y_train = pd.read_csv("../data/raw/train_labels.csv")
X_test  = pd.read_csv("../data/raw/test_features.csv")

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test :", X_test.shape)
# Out:
# X_train: (103023, 88)
# y_train: (104234, 3)
# X_test : (104234, 88)

# %%
print("X_train columns:")
print(X_train.columns.tolist())

print("\ny_train columns:")
print(y_train.columns.tolist())
# Out:
# X_train columns:
# ['hhid', 'com', 'weight', 'strata', 'utl_exp_ppp17', 'male', 'hsize', 'num_children5', 'num_children10', 'num_children18', 'age', 'owner', 'water', 'toilet', 'sewer', 'elect', 'water_source', 'sanitation_source', 'dweltyp', 'num_adult_female', 'num_adult_male', 'num_elderly', 'employed', 'sworkershh', 'share_secondary', 'educ_max', 'sfworkershh', 'any_nonagric', 'sector1d', 'region1', 'region2', 'region3', 'region4', 'region5', 'region6', 'region7', 'urban', 'consumed100', 'consumed200', 'consumed300', 'consumed400', 'consumed500', 'consumed600', 'consumed700', 'consumed800', 'consumed900', 'consumed1000', 'consumed1100', 'consumed1200', 'consumed1300', 'consumed1400', 'consumed1500', 'consumed1600', 'consumed1700', 'consumed1800', 'consumed1900', 'consumed2000', 'consumed2100', 'consumed2200', 'consumed2300', 'consumed2400', 'consumed2500', 'consumed2600', 'consumed2700', 'consumed2800', 'consumed2900', 'consumed3000', 'consumed3100', 'consumed3200', 'consumed3300', 'consumed3400', 'consumed3500', 'consumed3600', 'consumed3700', 'consumed3800', 'consumed3900', 'consumed4000', 'consumed4100', 'consumed4200', 'consumed4300', 'consumed4400', 'consumed4500', 'consumed4600', 'consumed4700', 'consumed4800', 'consumed4900', 'consumed5000', 'survey_id']
#
# y_train columns:
# ['survey_id', 'hhid', 'cons_ppp17']

# %%
train_df = X_train.merge(
    y_train,
    on=["survey_id", "hhid"],
    how="inner"
)

print("train_df shape:", train_df.shape)
train_df.head()
# Out:
# train_df shape: (0, 89)
# Empty DataFrame
# Columns: [hhid, com, weight, strata, utl_exp_ppp17, male, hsize, num_children5, num_children10, num_children18, age, owner, water, toilet, sewer, elect, water_source, sanitation_source, dweltyp, num_adult_female, num_adult_male, num_elderly, employed, sworkershh, share_secondary, educ_max, sfworkershh, any_nonagric, sector1d, region1, region2, region3, region4, region5, region6, region7, urban, consumed100, consumed200, consumed300, consumed400, consumed500, consumed600, consumed700, consumed800, consumed900, consumed1000, consumed1100, consumed1200, consumed1300, consumed1400, consumed1500, consumed1600, consumed1700, consumed1800, consumed1900, consumed2000, consumed2100, consumed2200, consumed2300, consumed2400, consumed2500, consumed2600, consumed2700, consumed2800, consumed2900, consumed3000, consumed3100, consumed3200, consumed3300, consumed3400, consumed3500, consumed3600, consumed3700, consumed3800, consumed3900, consumed4000, consumed4100, consumed4200, consumed4300, consumed4400, consumed4500, consumed4600, consumed4700, consumed4800, consumed4900, consumed5000, survey_id, cons_ppp17]
# Index: []
#
# [0 rows x 89 columns]

# %%
print(X_train[["survey_id", "hhid"]].dtypes)
print(y_train[["survey_id", "hhid"]].dtypes)
# Out:
# survey_id    int64
# hhid         int64
# dtype: object
# survey_id    int64
# hhid         int64
# dtype: object

# %%
common = set(zip(X_train.survey_id, X_train.hhid)) & \
         set(zip(y_train.survey_id, y_train.hhid))

len(common)
# Out:
# 0

# %%
print("X_train info:")
X_train.info()

print("\nX_test info:")
X_test.info()
# Out:
# X_train info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103023 entries, 0 to 103022
# Data columns (total 88 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hhid               103023 non-null  int64
#  1   com                103023 non-null  int64
#  2   weight             103023 non-null  int64
#  3   strata             103023 non-null  int64
#  4   utl_exp_ppp17      102740 non-null  float64
#  5   male               103023 non-null  object
#  6   hsize              103023 non-null  int64
#  7   num_children5      103023 non-null  int64
#  8   num_children10     103023 non-null  int64
#  9   num_children18     103023 non-null  int64
#  10  age                103023 non-null  int64
#  11  owner              103023 non-null  object
#  12  water              103023 non-null  object
#  13  toilet             103023 non-null  object
#  14  sewer              103023 non-null  object
#  15  elect              103023 non-null  object
#  16  water_source       103023 non-null  object
#  17  sanitation_source  103023 non-null  object
#  18  dweltyp            101901 non-null  object
#  19  num_adult_female   103023 non-null  int64
#  20  num_adult_male     103023 non-null  int64
#  21  num_elderly        103023 non-null  int64
#  22  employed           102969 non-null  object
#  23  sworkershh         103023 non-null  float64
#  24  share_secondary    103013 non-null  float64
#  25  educ_max           103012 non-null  object
#  26  sfworkershh        103023 non-null  float64
#  27  any_nonagric       103023 non-null  object
#  28  sector1d           87434 non-null   object
#  29  region1            103023 non-null  int64
#  30  region2            103023 non-null  int64
#  31  region3            103023 non-null  int64
#  32  region4            103023 non-null  int64
#  33  region5            103023 non-null  int64
#  34  region6            103023 non-null  int64
#  35  region7            103023 non-null  int64
#  36  urban              103023 non-null  object
#  37  consumed100        103009 non-null  object
#  38  consumed200        103003 non-null  object
#  39  consumed300        103005 non-null  object
#  40  consumed400        103007 non-null  object
#  41  consumed500        103006 non-null  object
#  42  consumed600        103003 non-null  object
#  43  consumed700        103007 non-null  object
#  44  consumed800        103003 non-null  object
#  45  consumed900        103007 non-null  object
#  46  consumed1000       102995 non-null  object
#  47  consumed1100       103003 non-null  object
#  48  consumed1200       102988 non-null  object
#  49  consumed1300       102980 non-null  object
#  50  consumed1400       102990 non-null  object
#  51  consumed1500       103000 non-null  object
#  52  consumed1600       103001 non-null  object
#  53  consumed1700       102995 non-null  object
#  54  consumed1800       102991 non-null  object
#  55  consumed1900       103003 non-null  object
#  56  consumed2000       103002 non-null  object
#  57  consumed2100       102999 non-null  object
#  58  consumed2200       102985 non-null  object
#  59  consumed2300       103002 non-null  object
#  60  consumed2400       103001 non-null  object
#  61  consumed2500       102986 non-null  object
#  62  consumed2600       102988 non-null  object
#  63  consumed2700       102999 non-null  object
#  64  consumed2800       103000 non-null  object
#  65  consumed2900       102995 non-null  object
#  66  consumed3000       102985 non-null  object
#  67  consumed3100       102986 non-null  object
#  68  consumed3200       102990 non-null  object
#  69  consumed3300       102987 non-null  object
#  70  consumed3400       102981 non-null  object
#  71  consumed3500       102978 non-null  object
#  72  consumed3600       102981 non-null  object
#  73  consumed3700       102972 non-null  object
#  74  consumed3800       102967 non-null  object
#  75  consumed3900       102968 non-null  object
#  76  consumed4000       102964 non-null  object
#  77  consumed4100       102964 non-null  object
#  78  consumed4200       102960 non-null  object
#  79  consumed4300       102947 non-null  object
#  80  consumed4400       102937 non-null  object
#  81  consumed4500       102947 non-null  object
#  82  consumed4600       102944 non-null  object
#  83  consumed4700       102946 non-null  object
#  84  consumed4800       102946 non-null  object
#  85  consumed4900       102935 non-null  object
#  86  consumed5000       102919 non-null  object
#  87  survey_id          103023 non-null  int64
# dtypes: float64(4), int64(20), object(64)
# memory usage: 69.2+ MB
#
# X_test info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104234 entries, 0 to 104233
# Data columns (total 88 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hhid               104234 non-null  int64
#  1   com                104234 non-null  int64
#  2   weight             104234 non-null  int64
#  3   strata             104234 non-null  int64
#  4   utl_exp_ppp17      104149 non-null  float64
#  5   male               104234 non-null  object
#  6   hsize              104234 non-null  int64
#  7   num_children5      104234 non-null  int64
#  8   num_children10     104234 non-null  int64
#  9   num_children18     104234 non-null  int64
#  10  age                104234 non-null  int64
#  11  owner              104234 non-null  object
#  12  water              104234 non-null  object
#  13  toilet             104234 non-null  object
#  14  sewer              104234 non-null  object
#  15  elect              104234 non-null  object
#  16  water_source       104234 non-null  object
#  17  sanitation_source  104234 non-null  object
#  18  dweltyp            103028 non-null  object
#  19  num_adult_female   104234 non-null  int64
#  20  num_adult_male     104234 non-null  int64
#  21  num_elderly        104234 non-null  int64
#  22  employed           104189 non-null  object
#  23  sworkershh         104234 non-null  float64
#  24  share_secondary    104211 non-null  float64
#  25  educ_max           104211 non-null  object
#  26  sfworkershh        104234 non-null  float64
#  27  any_nonagric       104234 non-null  object
#  28  sector1d           90105 non-null   object
#  29  region1            104234 non-null  int64
#  30  region2            104234 non-null  int64
#  31  region3            104234 non-null  int64
#  32  region4            104234 non-null  int64
#  33  region5            104234 non-null  int64
#  34  region6            104234 non-null  int64
#  35  region7            104234 non-null  int64
#  36  urban              104234 non-null  object
#  37  consumed100        104232 non-null  object
#  38  consumed200        104232 non-null  object
#  39  consumed300        104232 non-null  object
#  40  consumed400        104232 non-null  object
#  41  consumed500        104232 non-null  object
#  42  consumed600        104233 non-null  object
#  43  consumed700        104232 non-null  object
#  44  consumed800        104233 non-null  object
#  45  consumed900        104233 non-null  object
#  46  consumed1000       104230 non-null  object
#  47  consumed1100       104230 non-null  object
#  48  consumed1200       104229 non-null  object
#  49  consumed1300       104229 non-null  object
#  50  consumed1400       104229 non-null  object
#  51  consumed1500       104231 non-null  object
#  52  consumed1600       104230 non-null  object
#  53  consumed1700       104229 non-null  object
#  54  consumed1800       104230 non-null  object
#  55  consumed1900       104230 non-null  object
#  56  consumed2000       104231 non-null  object
#  57  consumed2100       104230 non-null  object
#  58  consumed2200       104227 non-null  object
#  59  consumed2300       104231 non-null  object
#  60  consumed2400       104233 non-null  object
#  61  consumed2500       104230 non-null  object
#  62  consumed2600       104227 non-null  object
#  63  consumed2700       104232 non-null  object
#  64  consumed2800       104229 non-null  object
#  65  consumed2900       104227 non-null  object
#  66  consumed3000       104224 non-null  object
#  67  consumed3100       104221 non-null  object
#  68  consumed3200       104219 non-null  object
#  69  consumed3300       104214 non-null  object
#  70  consumed3400       104212 non-null  object
#  71  consumed3500       104210 non-null  object
#  72  consumed3600       104211 non-null  object
#  73  consumed3700       104205 non-null  object
#  74  consumed3800       104199 non-null  object
#  75  consumed3900       104194 non-null  object
#  76  consumed4000       104196 non-null  object
#  77  consumed4100       104194 non-null  object
#  78  consumed4200       104190 non-null  object
#  79  consumed4300       104182 non-null  object
#  80  consumed4400       104182 non-null  object
#  81  consumed4500       104180 non-null  object
#  82  consumed4600       104178 non-null  object
#  83  consumed4700       104182 non-null  object
#  84  consumed4800       104178 non-null  object
#  85  consumed4900       104178 non-null  object
#  86  consumed5000       104168 non-null  object
#  87  survey_id          104234 non-null  int64
# dtypes: float64(4), int64(20), object(64)
# memory usage: 70.0+ MB

# %%
# Combine train and test ONLY for EDA
full_X = pd.concat(
    [X_train.assign(_set="train"), 
     X_test.assign(_set="test")],
    axis=0
)

# %%
missing_pct = (full_X.isna().sum() / len(full_X)) * 100
missing_pct = missing_pct[missing_pct > 0].sort_values(ascending=False)

missing_pct.head(15)
# Out:
# sector1d         14.338720
# dweltyp           1.123243
# utl_exp_ppp17     0.177557
# consumed5000      0.082024
# consumed4900      0.069479
# consumed4400      0.066584
# consumed4600      0.065137
# consumed4800      0.064172
# consumed4500      0.062724
# consumed4700      0.062242
# consumed4300      0.061759
# consumed4200      0.051627
# consumed4100      0.047767
# employed          0.047767
# consumed4000      0.046802
# dtype: float64

# %%
# DROP very high-missing / useless column
if "sector1d" in X_train.columns:
    X_train = X_train.drop(columns=["sector1d"])
    X_test  = X_test.drop(columns=["sector1d"])


# CATEGORICAL → MODE 
cat_cols = ["dweltyp", "employed"]

for col in cat_cols:
    mode_val = X_train[col].mode()[0]
    X_train[col] = X_train[col].fillna(mode_val)
    X_test[col]  = X_test[col].fillna(mode_val)


#  NUMERIC → MEDIAN 
num_col = "utl_exp_ppp17"
median_val = X_train[num_col].median()

X_train[num_col] = X_train[num_col].fillna(median_val)
X_test[num_col]  = X_test[num_col].fillna(median_val)


consumed_cols = [c for c in X_train.columns if c.startswith("consumed")]

X_train[consumed_cols] = X_train[consumed_cols].fillna(0)
X_test[consumed_cols]  = X_test[consumed_cols].fillna(0)


#  FINAL CHECK
print("Train missing:", X_train.isna().sum().sum())
print("Test missing :", X_test.isna().sum().sum())
# Out:
# Train missing: 21
# Test missing : 46

# %%
cat_cols_all = X_train.select_dtypes(include="object").columns

for col in cat_cols_all:
    mode_val = X_train[col].mode()[0]
    X_train[col] = X_train[col].fillna(mode_val)
    X_test[col]  = X_test[col].fillna(mode_val)


# FINAL FINAL CHECK
print("Train missing:", X_train.isna().sum().sum())
print("Test missing :", X_test.isna().sum().sum())
# Out:
# Train missing: 10
# Test missing : 23

# %%
num_cols_all = X_train.select_dtypes(include=["int64", "float64"]).columns

for col in num_cols_all:
    median_val = X_train[col].median()
    X_train[col] = X_train[col].fillna(median_val)
    X_test[col]  = X_test[col].fillna(median_val)


# FINAL ABSOLUTE CHECK
print("Train missing:", X_train.isna().sum().sum())
print("Test missing :", X_test.isna().sum().sum())
# Out:
# Train missing: 0
# Test missing : 0

# %%
cat_cols = X_train.select_dtypes(include=["object"]).columns
print(len(cat_cols))
print(cat_cols.tolist())
# Out:
# 64
# ['male', 'owner', 'water', 'toilet', 'sewer', 'elect', 'water_source', 'sanitation_source', 'dweltyp', 'employed', 'educ_max', 'any_nonagric', 'sector1d', 'urban', 'consumed100', 'consumed200', 'consumed300', 'consumed400', 'consumed500', 'consumed600', 'consumed700', 'consumed800', 'consumed900', 'consumed1000', 'consumed1100', 'consumed1200', 'consumed1300', 'consumed1400', 'consumed1500', 'consumed1600', 'consumed1700', 'consumed1800', 'consumed1900', 'consumed2000', 'consumed2100', 'consumed2200', 'consumed2300', 'consumed2400', 'consumed2500', 'consumed2600', 'consumed2700', 'consumed2800', 'consumed2900', 'consumed3000', 'consumed3100', 'consumed3200', 'consumed3300', 'consumed3400', 'consumed3500', 'consumed3600', 'consumed3700', 'consumed3800', 'consumed3900', 'consumed4000', 'consumed4100', 'consumed4200', 'consumed4300', 'consumed4400', 'consumed4500', 'consumed4600', 'consumed4700', 'consumed4800', 'consumed4900', 'consumed5000']

# %%
for col in cat_cols:
    mode_val = X_train[col].mode()[0]
    X_train[col] = X_train[col].fillna(mode_val)
    X_test[col] = X_test[col].fillna(mode_val)

print(X_train[cat_cols].isna().sum().sum(),
      X_test[cat_cols].isna().sum().sum())
# Out:
# 0 0

# %%
for col in cat_cols:
    X_train[col] = X_train[col].str.lower().str.strip()
    X_test[col] = X_test[col].str.lower().str.strip()

# %%
low_card = [c for c in cat_cols if X_train[c].nunique() <= 10]
high_card = [c for c in cat_cols if X_train[c].nunique() > 10]

print(len(low_card), len(high_card))
# Out:
# 63 1

# %%
print("Train missing:", X_train.isna().sum().sum())
print("Test missing:", X_test.isna().sum().sum())
# Out:
# Train missing: 293
# Test missing: 108

# %%
X_train.isna().sum()[X_train.isna().sum() > 0]
# Out:
# utl_exp_ppp17      283
# share_secondary     10
# dtype: int64

# %%
X_test.isna().sum()[X_test.isna().sum() > 0]
# Out:
# utl_exp_ppp17      85
# share_secondary    23
# dtype: int64

# %%
med_utl = X_train["utl_exp_ppp17"].median()
med_share = X_train["share_secondary"].median()

# %%
X_train["utl_exp_ppp17"] = X_train["utl_exp_ppp17"].fillna(med_utl)
X_test["utl_exp_ppp17"]  = X_test["utl_exp_ppp17"].fillna(med_utl)

X_train["share_secondary"] = X_train["share_secondary"].fillna(med_share)
X_test["share_secondary"]  = X_test["share_secondary"].fillna(med_share)

# %%
print("Train missing:", X_train.isna().sum().sum())
print("Test missing :", X_test.isna().sum().sum())
# Out:
# Train missing: 0
# Test missing : 0

# %%
# fresh y from original y_train
y = y_train["cons_ppp17"]

print(y.shape)
print(X_train.shape)
# Out:
# (104234,)
# (103023, 88)

# %%
y = y.iloc[:len(X_train)]

print(X_train.shape)
print(y.shape)
# Out:
# (103023, 88)
# (103023,)

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train,
    y,
    test_size=0.2,
    random_state=42
)

print(X_tr.shape, X_val.shape)
print(y_tr.shape, y_val.shape)
# Out:
# (82418, 88) (20605, 88)
# (82418,) (20605,)

# %%
# fix male column
if X_tr["male"].dtype == "object":
    X_tr["male"] = X_tr["male"].map({"male": 1, "female": 0})
    X_val["male"] = X_val["male"].map({"male": 1, "female": 0})

# %%
obj_cols = X_tr.select_dtypes(include="object").columns
obj_cols
# Out:
# Index(['owner', 'water', 'toilet', 'sewer', 'elect', 'water_source',
#        'sanitation_source', 'dweltyp', 'employed', 'educ_max', 'any_nonagric',
#        'sector1d', 'urban', 'consumed100', 'consumed200', 'consumed300',
#        'consumed400', 'consumed500', 'consumed600', 'consumed700',
#        'consumed800', 'consumed900', 'consumed1000', 'consumed1100',
#        'consumed1200', 'consumed1300', 'consumed1400', 'consumed1500',
#        'consumed1600', 'consumed1700', 'consumed1800', 'consumed1900',
#        'consumed2000', 'consumed2100', 'consumed2200', 'consumed2300',
#        'consumed2400', 'consumed2500', 'consumed2600', 'consumed2700',
#        'consumed2800', 'consumed2900', 'consumed3000', 'consumed3100',
#        'consumed3200', 'consumed3300', 'consumed3400', 'consumed3500',
#        'consumed3600', 'consumed3700', 'consumed3800', 'consumed3900',
#        'consumed4000', 'consumed4100', 'consumed4200', 'consumed4300',
#        'consumed4400', 'consumed4500', 'consumed4600', 'consumed4700',
#        'consumed4800', 'consumed4900', 'consumed5000'],
#       dtype='object')

# %%
for col in obj_cols:
    X_tr[col] = X_tr[col].astype("category").cat.codes
    X_val[col] = X_val[col].astype("category").cat.codes

# %%
X_tr.dtypes.value_counts()
# Out:
# int8       63
# int64      21
# float64     4
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train,
    y,
    test_size=0.2,
    random_state=42
)

print(X_tr.shape, X_val.shape)
print(y_tr.shape, y_val.shape)
# Out:
# (82418, 88) (20605, 88)
# (82418,) (20605,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

model = LinearRegression()
model.fit(X_tr, y_tr)

val_pred = model.predict(X_val)
rmse = np.sqrt(mean_squared_error(y_val, val_pred))

print("Baseline RMSE:", rmse)
# Out:
# Baseline RMSE: 10.386115096417404

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
import numpy as np

ridge = Ridge(alpha=1.0)
ridge.fit(X_tr, y_tr)

ridge_pred = ridge.predict(X_val)
ridge_rmse = np.sqrt(mean_squared_error(y_val, ridge_pred))

ridge_rmse
# Out:
# np.float64(10.386112312142439)

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.001, max_iter=10000)
lasso.fit(X_tr, y_tr)

lasso_pred = lasso.predict(X_val)
lasso_rmse = np.sqrt(mean_squared_error(y_val, lasso_pred))

lasso_rmse
# Out:
# np.float64(10.385786354848289)

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train,
    y,
    test_size=0.2,
    random_state=42
)

print(X_tr.shape, X_val.shape)
print(y_tr.shape, y_val.shape)
# Out:
# (82418, 88) (20605, 88)
# (82418,) (20605,)

# %%
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

cb = CatBoostRegressor(
    iterations=500,
    depth=6,
    learning_rate=0.05,
    loss_function="RMSE",
    verbose=100
)

cb.fit(X_tr, y_tr)
val_pred = cb.predict(X_val)
np.sqrt(mean_squared_error(y_val, val_pred))
# Out:
# 0:	learn: 9.9401680	total: 63.3ms	remaining: 31.6s
# 100:	learn: 9.3197445	total: 775ms	remaining: 3.06s
# 200:	learn: 9.1758134	total: 1.4s	remaining: 2.08s
# 300:	learn: 9.0352077	total: 2.01s	remaining: 1.33s
# 400:	learn: 8.9299424	total: 2.81s	remaining: 694ms
# 499:	learn: 8.8505073	total: 3.67s	remaining: 0us
# np.float64(9.316823010643972)

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train,
    y,
    test_size=0.2,
    random_state=42
)

print(X_tr.shape, X_val.shape)
print(y_tr.shape, y_val.shape)
# Out:
# (82418, 88) (20605, 88)
# (82418,) (20605,)

# %%
y_tr_log = np.log1p(y_tr)
y_val_log = np.log1p(y_val)

# %%
# keep only numeric columns
num_cols = X_tr.select_dtypes(include=["int64", "float64"]).columns

X_tr_num = X_tr[num_cols]
X_val_num = X_val[num_cols]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_tr_num, y_tr_log)

val_pred_log = model.predict(X_val_num)
val_pred = np.expm1(val_pred_log)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y_val, val_pred))
rmse
# Out:
# np.float64(10.68847505651696)

# %%
cat_cols = X_tr.select_dtypes(include=["object"]).columns.tolist()
len(cat_cols)
# Out:
# 64

# %%
from catboost import CatBoostRegressor

model = CatBoostRegressor(
    iterations=1000,
    learning_rate=0.05,
    depth=8,
    loss_function="RMSE",
    eval_metric="RMSE",
    random_seed=42,
    verbose=100
)

model.fit(
    X_tr,
    y_tr,
    eval_set=(X_val, y_val),
    cat_features=cat_cols,
    use_best_model=True
)
# Out:
# 0:	learn: 9.9280801	test: 10.3749201	best: 10.3749201 (0)	total: 101ms	remaining: 1m 41s
# 100:	learn: 9.2635146	test: 9.6622393	best: 9.6622393 (100)	total: 4.39s	remaining: 39.1s
# 200:	learn: 9.1453466	test: 9.5747128	best: 9.5746908 (199)	total: 7.57s	remaining: 30.1s
# 300:	learn: 8.9918707	test: 9.4539938	best: 9.4539938 (300)	total: 10.8s	remaining: 25.1s
# 400:	learn: 8.8685819	test: 9.3611824	best: 9.3611824 (400)	total: 14.3s	remaining: 21.4s
# 500:	learn: 8.8008808	test: 9.3193503	best: 9.3189634 (498)	total: 17.6s	remaining: 17.5s
# 600:	learn: 8.7487652	test: 9.2950294	best: 9.2950226 (599)	total: 20.8s	remaining: 13.8s
# 700:	learn: 8.6956516	test: 9.2754783	best: 9.2754262 (698)	total: 24.9s	remaining: 10.6s
# 800:	learn: 8.6521618	test: 9.2635020	best: 9.2635020 (800)	total: 28.4s	remaining: 7.04s
# 900:	learn: 8.5922872	test: 9.2492265	best: 9.2491331 (897)	total: 32s	remaining: 3.51s
# 999:	learn: 8.5374425	test: 9.2374176	best: 9.2373450 (997)	total: 35.2s	remaining: 0us
#
# bestTest = 9.237345036
# bestIteration = 997
#
# Shrink model to first 998 iterations.

# %%
y_tr_log = np.log1p(y_tr)
y_val_log = np.log1p(y_val)

# %%
model = CatBoostRegressor(
    iterations=3000,
    learning_rate=0.03,
    depth=10,
    l2_leaf_reg=5,
    loss_function="RMSE",
    eval_metric="RMSE",
    random_seed=42,
    verbose=200
)

model.fit(
    X_tr,
    y_tr_log,
    eval_set=(X_val, y_val_log),
    cat_features=cat_cols,
    sample_weight=X_tr["weight"],
    use_best_model=True
)
# Out:
# 0:	learn: 0.6212410	test: 0.6294793	best: 0.6294793 (0)	total: 75.4ms	remaining: 3m 46s
# 200:	learn: 0.6124970	test: 0.6256353	best: 0.6256353 (200)	total: 7.27s	remaining: 1m 41s
# 400:	learn: 0.6068888	test: 0.6232199	best: 0.6232199 (400)	total: 13.2s	remaining: 1m 25s
# 600:	learn: 0.5504404	test: 0.5741543	best: 0.5741543 (600)	total: 24.9s	remaining: 1m 39s
# 800:	learn: 0.5169816	test: 0.5586688	best: 0.5586688 (800)	total: 37s	remaining: 1m 41s
# 1000:	learn: 0.4936390	test: 0.5522101	best: 0.5522101 (1000)	total: 48.6s	remaining: 1m 36s
# 1200:	learn: 0.4748275	test: 0.5471919	best: 0.5471919 (1200)	total: 1m 2s	remaining: 1m 33s
# 1400:	learn: 0.4598728	test: 0.5439954	best: 0.5439906 (1399)	total: 1m 14s	remaining: 1m 25s
# 1600:	learn: 0.4457386	test: 0.5414402	best: 0.5414402 (1600)	total: 1m 28s	remaining: 1m 17s
# 1800:	learn: 0.4324409	test: 0.5397817	best: 0.5397817 (1800)	total: 1m 41s	remaining: 1m 7s
# 2000:	learn: 0.4214954	test: 0.5384222	best: 0.5384222 (2000)	total: 1m 54s	remaining: 57.2s
# 2200:	learn: 0.4114684	test: 0.5374485	best: 0.5374485 (2200)	total: 2m 8s	remaining: 46.6s
# 2400:	learn: 0.4014035	test: 0.5367312	best: 0.5367129 (2391)	total: 2m 20s	remaining: 35.2s
# 2600:	learn: 0.3925640	test: 0.5360066	best: 0.5359902 (2596)	total: 2m 35s	remaining: 23.8s
# 2800:	learn: 0.3845318	test: 0.5354817	best: 0.5354817 (2800)	total: 2m 49s	remaining: 12s
# 2999:	learn: 0.3765448	test: 0.5351434	best: 0.5351369 (2989)	total: 3m 1s	remaining: 0us
#
# bestTest = 0.5351369042
# bestIteration = 2989
#
# Shrink model to first 2990 iterations.
